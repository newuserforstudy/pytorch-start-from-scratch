# %% [markdown]
# ### 1 NLP路线分析
# NLP的主要技术方向![image.png](attachment:image.png)

# %% [markdown]
# ### 2 NLP 从入门到实战的流程
# NLP从入门到实战![image.png](attachment:image.png)
#
# 说明：高级任务即主要方向中的2、3

# %% [markdown]
# ### 3 推荐参考书
# 虽然每一本书都不是特别的全面，有的还特别的差，但是书是入门到进阶的引路人！！热爱它！
#
# 《中文信息处理发展报告》中文信息学会 http://www.cipsc.org.cn/
# 《自然语言处理简明教程》冯志伟
# 《NLP汉语自然语言处理：原理与实践》郑捷
# 《自然语言处理技术：入门与实践》兰红云
