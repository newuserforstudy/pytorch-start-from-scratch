# %% [markdown]
# ### 1 pytorch解决不同图像处理任务的包 torchvision.models
# 官网：https://pytorch.org/docs/stable/torchvision/models.html#torchvision-models
#
# 任务包括：
#
# 图像分类： image classification
# 语义分割：semantic segmentation
# 目标检测：object detection
# 实例分割：instance segmentation
# 人关键点检测：person keypoint detection
# 视频分类：video classification

# %% [markdown]
# ### 2 torchvision.models包的源码查看和结果解析
# 该包的\__init\__\.py:
#
# from .alexnet import *       &emsp;&emsp; &emsp;  导入torchvision.models包alexnet模块中的所有
# from .resnet import *        &emsp;&emsp; &emsp;导入torchvision.models包resnet模块中的所有
# from .vgg import *          &emsp;&emsp; &emsp;导入 torchvision.models包vgg模块中的所有
# from .squeezenet import *     &emsp;&emsp; &emsp;导入 torchvision.models包squeezenet模块中的所有
# from .inception import *     &emsp;&emsp; &emsp;导入torchvision.models包inception模块中的所有
# from .densenet import *      &emsp;&emsp; &emsp;导入torchvision.models包densenet模块中的所有
# from .googlenet import *     &emsp;&emsp; &emsp;导入torchvision.models包googlenet模块中的所有
# from .mobilenet import *     &emsp;&emsp; &emsp;导入 torchvision.models包mobilenet 模块中的所有
# from .mnasnet import *       &emsp;&emsp; &emsp;导入torchvision.models包mnasnet模块中的所有
# from .shufflenetv2 import *   &emsp;&emsp; &emsp;导入torchvision.models包shufflenetv2模块中的所有
# from . import segmentation    &emsp;&emsp; &emsp;导入torchvision.models包segmentation包
# from . import detection      &emsp;&emsp; &emsp;导入torchvision.models包detection包
# from . import video         &emsp;&emsp; &emsp;导入torchvision.models包video包
#
# 文件结构：
# ![jupyter](./torch_models.png)

# %% [markdown]
# ### 3 alexnet模块
# \__all\__\= ['AlexNet', 'alexnet']
#
# 使用alexnet架构：2种方法
# alexnet = models.alexnet() 随机初始化权重
# alexnet = models.alexnet(pretrained=True) 使用预训练权重imagenet数据集

# %% [markdown]
# ### 4 vgg模块
# \__all\__= ['VGG', 'vgg11', 'vgg11_bn', 'vgg13', 'vgg13_bn', 'vgg16', 'vgg16_bn',  'vgg19_bn', 'vgg19']
# 使用8种vgg架构：每种2种方法
# vgg11 = models.vgg11() 随机初始化权重
# vgg11 = models.vgg11(pretrained=True) 使用预训练权重
#
# vgg11_bn = models.vgg11_bn() 随机初始化权重
# vgg11_bn = models.vgg11_bn(pretrained=True) 使用预训练权重
#
# vgg13 = models.vgg13() 随机初始化权重
# vgg13 = models.vgg13(pretrained=True) 使用预训练权重
#
# vgg13_bn = models.vgg13_bn() 随机初始化权重
# vgg13_bn = models.vgg13_bn(pretrained=True) 使用预训练权重
#
# vgg16 = models.vgg16() 随机初始化权重
# vgg16 = models.vgg16(pretrained=True) 使用预训练权重
#
# vgg16_bn = models.vgg16_bn() 随机初始化权重
# vgg16_bn = models.vgg16_bn(pretrained=True) 使用预训练权重
#
# vgg19 = models.vgg19() 随机初始化权重
# vgg19 = models.vgg19(pretrained=True) 使用预训练权重
#
# vgg19_bn = models.vgg19_bn() 随机初始化权重
# vgg19_bn = models.vgg19_bn(pretrained=True) 使用预训练权重

# %% [markdown]
# ### 5 resnet模块
# \__all\__=['ResNet','resnet18','resnet34','resnet50','resnet101','resnet152','resnext50_32x4d','resnext101_32x8d','wide_resnet50_2', 'wide_resnet101_2']
# 使用9种resnet架构：每种2种方法
# resnet18 = models.resnet18() 随机初始化权重
# resnet18 = models.resnet18(pretrained=True) 使用预训练权重
#
# resnet34 = models.resnet34() 随机初始化权重
# resnet34 = models.resnet34(pretrained=True) 使用预训练权重
#
# resnet50 = models.resnet50() 随机初始化权重
# resnet50 = models.resnet50(pretrained=True) 使用预训练权重
#
# resnet101 = models.resnet101() 随机初始化权重
# resnet101 = models.resnet101(pretrained=True) 使用预训练权重
#
# resnet152 = models.resnet152() 随机初始化权重
# resnet152 = models.resnet152(pretrained=True) 使用预训练权重
#
# resnet50_32x4d = models.resnet50_32x4d() 随机初始化权重
# resnet50_32x4d = models.resnet50_32x4d(pretrained=True) 使用预训练权重
#
# resnext101_32x8d = models.resnext101_32x8d() 随机初始化权重
# resnext101_32x8d = models.resnext101_32x8d(pretrained=True) 使用预训练权重
#
# wide_resnet50_2 = models.wide_resnet50_2() 随机初始化权重
# wide_resnet50_2 = models.wide_resnet50_2(pretrained=True) 使用预训练权重
#
# wide_resnet101_2 = models.wide_resnet101_2() 随机初始化权重
# wide_resnet101_2 = models.wide_resnet101_2(pretrained=True) 使用预训练权重

# %% [markdown]
# ### 6 squeezenet模块
# \__all\__=['SqueezeNet', 'squeezenet1_0', 'squeezenet1_1']
# 使用2种squeezenet架构：每种2种方法
# squeezenet1_0 = models.squeezenet1_0() 随机初始化权重
# squeezenet1_0 = models.squeezenet1_0(pretrained=True) 使用预训练权重
#
# squeezenet1_1 = models.squeezenet1_1() 随机初始化权重
# squeezenet1_1 = models.squeezenet1_1(pretrained=True) 使用预训练权重

# %% [markdown]
# ### 7 inception模块
# \__all\__=['DenseNet', 'densenet121', 'densenet169', 'densenet201', 'densenet161']
# 使用4种inception架构：每种2种方法
#
# densenet121 = models.densenet121() 随机初始化权重
# densenet121 = models.densenet121(pretrained=True) 使用预训练权重
#
# densenet169 = models.densenet169() 随机初始化权重
# densenet169 = models.densenet169(pretrained=True) 使用预训练权重
#
# densenet201 = models.densenet201() 随机初始化权重
# densenet201 = models.densenet201(pretrained=True) 使用预训练权重
#
# densenet161 = models.densenet161() 随机初始化权重
# densenet161 = models.densenet161(pretrained=True) 使用预训练权重

# %% [markdown]
# ### 8 googlenet模块
# \__all\__=['GoogLeNet', 'googlenet']
# 使用1种googlenet架构：每种2种方法
#
# googlenet = models.googlenet() 随机初始化权重
# googlenet = models.googlenet(pretrained=True) 使用预训练权重

# %% [markdown]
# ### 9 mobilenet模块
# \__all\__=['MobileNetV2', 'mobilenet_v2']
# 使用1种mobilenet架构：每种2种方法
#
# mobilenet_v2 = models.mobilenet_v2() 随机初始化权重
# mobilenet_v2 = models.mobilenet_v2(pretrained=True) 使用预训练权重

# %% [markdown]
# ### 10 mnasnet模块
# \__all\__=['MNASNet', 'mnasnet0_5', 'mnasnet0_75', 'mnasnet1_0', 'mnasnet1_3']
# 使用4种mnasnet架构：每种2种方法
#
# mnasnet0_5 = models.mnasnet0_5() 随机初始化权重
# mnasnet0_5 = models.mnasnet0_5(pretrained=True) 使用预训练权重
#
# mnasnet0_75 = models.mnasnet0_75() 随机初始化权重
# mnasnet0_75 = models.mnasnet0_75(pretrained=True) 使用预训练权重
#
# mnasnet1_0 = models.mnasnet1_0() 随机初始化权重
# mnasnet1_0 = models.mnasnet1_0(pretrained=True) 使用预训练权重
#
# mnasnet1_3 = models.mnasnet1_3() 随机初始化权重
# mnasnet1_3 = models.mnasnet1_3(pretrained=True) 使用预训练权重

# %% [markdown]
# ### 11 shufflenetv2模块
# \__all\__=['ShuffleNetV2', 'shufflenet_v2_x0_5', 'shufflenet_v2_x1_0','shufflenet_v2_x1_5', 'shufflenet_v2_x2_0']
# 使用4种mnasnet架构：每种2种方法
#
# shufflenet_v2_x0_5 = models.shufflenet_v2_x0_5() 随机初始化权重
# shufflenet_v2_x0_5 = models.shufflenet_v2_x0_5(pretrained=True) 使用预训练权重
#
# shufflenet_v2_x1_0 = models.shufflenet_v2_x1_0() 随机初始化权重
# shufflenet_v2_x1_0 = models.shufflenet_v2_x1_0(pretrained=True) 使用预训练权重
#
# shufflenet_v2_x1_5 = models.shufflenet_v2_x1_5() 随机初始化权重
# shufflenet_v2_x1_5 = models.shufflenet_v2_x1_5(pretrained=True) 使用预训练权重
#
# shufflenet_v2_x2_0 = models.shufflenet_v2_x2_0() 随机初始化权重
# shufflenet_v2_x2_0 = models.shufflenet_v2_x2_0(pretrained=True) 使用预训练权重

# %% [markdown]
# ### 12 segmentation包
# \__init\__\.py :
# from .segmentation import *
# from .fcn import *
# from .deeplabv3 import *
#
# segmentation包的segmentation模块
# \__all\__=['fcn_resnet50', 'fcn_resnet101', 'deeplabv3_resnet50', 'deeplabv3_resnet101']
# 使用4种mnasnet架构：每种2种方法
#
# fcn_resnet50 = models.segmentation.fcn_resnet50() 随机初始化权重
# segmentation.fcn_resnet50 =models.segmentation.fcn_resnet50(pretrained=True) 使用预训练权重COCO数据集
#
# fcn_resnet101 = models.segmentation.fcn_resnet101() 随机初始化权重
# fcn_resnet101 = models.segmentation.fcn_resnet101(pretrained=True) 使用预训练权重
#
# deeplabv3_resnet50 = models.segmentation.deeplabv3_resnet50() 随机初始化权重
# deeplabv3_resnet50 = models.segmentation.deeplabv3_resnet50(pretrained=True) 使用预训练权重
#
# deeplabv3_resnet101 = models.segmentation.deeplabv3_resnet101() 随机初始化权重
# deeplabv3_resnet101 = models.segmentation.deeplabv3_resnet101(pretrained=True) 使用预训练权重

# %% [markdown]
# ### 13 detection包
# \__init\__\.py:
# from .faster_rcnn import *
# from .mask_rcnn import *
# from .keypoint_rcnn import *
#
# detection包的faster_rcnn模块
# \__all\__=["FasterRCNN", "fasterrcnn_resnet50_fpn"]
# fasterrcnn_resnet50_fpn = models.detection.fasterrcnn_resnet50_fpn() 随机初始化权重
# fasterrcnn_resnet50_fpn = models.detection.fasterrcnn_resnet50_fpn(pretrained=True) 使用预训练权重COCO数据集
#
# detection包的mask_rcnn模块
# \__all\__=["MaskRCNN", "maskrcnn_resnet50_fpn"]
# maskrcnn_resnet50_fpn = models.detection.maskrcnn_resnet50_fpn() 随机初始化权重
# maskrcnn_resnet50_fpn = models.detection.maskrcnn_resnet50_fpn(pretrained=True) 使用预训练权重COCO数据集
#
# detection包的keypoint_rcnn模块
# \__all\__=["KeypointRCNN", "keypointrcnn_resnet50_fpn"]
# keypointrcnn_resnet50_fpn = models.detection.keypointrcnn_resnet50_fpn() 随机初始化权重
# keypointrcnn_resnet50_fpn = models.detection.keypointrcnn_resnet50_fpn(pretrained=True) 使用预训练权重COCO数据集

# %% [markdown]
# ### 14 video包
# \__init\__\.py:
# from .resnet import *
#
# video包的resnet模块
# \__all\__=['r3d_18', 'mc3_18', 'r2plus1d_18']
# r3d_18 = models.video.r3d_18() 随机初始化权重
# r3d_18 = models.video.r3d_18(pretrained=True) 使用预训练权重Kinetics-400数据集
#
# mc3_18 = models.video.mc3_18() 随机初始化权重
# mc3_18 = models.video.mc3_18(pretrained=True) 使用预训练权重Kinetics-400数据集
#
# r2plus1d_18 = models.video.r2plus1d_18() 随机初始化权重
# r2plus1d_18 = models.video.r2plus1d_18(pretrained=True) 使用预训练权重Kinetics-400数据集

# %% [markdown]
# ### 15 查看网络的组成结构

# %%
from torchvision import models

# %%
models.alexnet()
# Out:
# AlexNet(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(11, 11), stride=(4, 4), padding=(2, 2))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (3): Conv2d(64, 192, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (4): ReLU(inplace=True)
#     (5): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (6): Conv2d(192, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (7): ReLU(inplace=True)
#     (8): Conv2d(384, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (9): ReLU(inplace=True)
#     (10): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace=True)
#     (12): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(6, 6))
#   (classifier): Sequential(
#     (0): Dropout(p=0.5, inplace=False)
# ...

# %%
models.vgg16_bn()
# Out:
# VGG(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (4): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): ReLU(inplace=True)
#     (6): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (7): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (9): ReLU(inplace=True)
#     (10): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (12): ReLU(inplace=True)
# ...

# %%
models.googlenet()
# Out:
# GoogLeNet(
#   (conv1): BasicConv2d(
#     (conv): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (maxpool1): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=True)
#   (conv2): BasicConv2d(
#     (conv): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (conv3): BasicConv2d(
#     (conv): Conv2d(64, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (maxpool2): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=True)
#   (inception3a): Inception(
#     (branch1): BasicConv2d(
#       (conv): Conv2d(192, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
# ...

# %%
models.inception_v3()
# Out:
# Inception3(
#   (Conv2d_1a_3x3): BasicConv2d(
#     (conv): Conv2d(3, 32, kernel_size=(3, 3), stride=(2, 2), bias=False)
#     (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (Conv2d_2a_3x3): BasicConv2d(
#     (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), bias=False)
#     (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (Conv2d_2b_3x3): BasicConv2d(
#     (conv): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (Conv2d_3b_1x1): BasicConv2d(
#     (conv): Conv2d(64, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (bn): BatchNorm2d(80, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (Conv2d_4a_3x3): BasicConv2d(
#     (conv): Conv2d(80, 192, kernel_size=(3, 3), stride=(1, 1), bias=False)
# ...

# %%
models.resnet34()
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# ...

# %%
models.densenet161()
# Out:
# DenseNet(
#   (features): Sequential(
#     (conv0): Conv2d(3, 96, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (norm0): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu0): ReLU(inplace=True)
#     (pool0): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (denseblock1): _DenseBlock(
#       (denselayer1): _DenseLayer(
#         (norm1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(96, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer2): _DenseLayer(
# ...

# %%
models.mobilenet_v2()
# Out:
# MobileNetV2(
#   (features): Sequential(
#     (0): ConvBNReLU(
#       (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (2): ReLU6(inplace=True)
#     )
#     (1): InvertedResidual(
#       (conv): Sequential(
#         (0): ConvBNReLU(
#           (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#           (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (2): ReLU6(inplace=True)
#         )
#         (1): Conv2d(32, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (2): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (2): InvertedResidual(
#       (conv): Sequential(
#         (0): ConvBNReLU(
#           (0): Conv2d(16, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
# ...

# %%
models.shufflenet_v2_x0_5()
# Out:
# ShuffleNetV2(
#   (conv1): Sequential(
#     (0): Conv2d(3, 24, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#   )
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (stage2): Sequential(
#     (0): InvertedResidual(
#       (branch1): Sequential(
#         (0): Conv2d(24, 24, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=24, bias=False)
#         (1): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): Conv2d(24, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (3): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (4): ReLU(inplace=True)
#       )
#       (branch2): Sequential(
#         (0): Conv2d(24, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
# ...

# %%
models.mnasnet0_5()
# Out:
# MNASNet(
#   (layers): Sequential(
#     (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(32, eps=1e-05, momentum=0.00029999999999996696, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#     (4): BatchNorm2d(32, eps=1e-05, momentum=0.00029999999999996696, affine=True, track_running_stats=True)
#     (5): ReLU(inplace=True)
#     (6): Conv2d(32, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (7): BatchNorm2d(16, eps=1e-05, momentum=0.00029999999999996696, affine=True, track_running_stats=True)
#     (8): Sequential(
#       (0): _InvertedResidual(
#         (layers): Sequential(
#           (0): Conv2d(16, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (1): BatchNorm2d(48, eps=1e-05, momentum=0.00029999999999996696, affine=True, track_running_stats=True)
# ...

# %% [markdown]
# ### 备注：关于图像处理具体任务后续以实例进行详解，这里介绍模型以备后续使用。
